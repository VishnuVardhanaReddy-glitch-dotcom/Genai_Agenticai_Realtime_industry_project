# %%
msg = 'hello goodmorning'

# %%
msg[6]
# Out:
# 'g'

# %%
msg[6:10]
# Out:
# 'good'

# %%
msg[:7]
# Out:
# 'hello g'

# %%
msg[2:]
# Out:
# 'llo goodmorning'

# %%
msg[-8:-1]
# Out:
# 'dmornin'

# %%
msg[::-1]
# Out:
# 'gninromdoog olleh'

# %%
msg[::4]
# Out:
# 'hoorg'
