# %% [markdown]
# # arithematic operators
# + - * / // % **
#
# # comparison operators
# == != > < <= >=
#
# # logical operators
# and or not
#
# # assignment operators
# += -= *= /= //= %= **=
#
# # identity operators
# is  is not
#
# # membership operators
# in  not in
#
# # bitwise operators
# & | ^ ~ << >>
